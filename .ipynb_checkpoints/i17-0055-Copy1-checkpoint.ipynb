# %%
import numpy as np
import pandas as pd

# %%
import nltk
import re

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer

# %%
from nltk.util import ngrams
from collections import Counter

# %%
# !pip install wordcloud

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
from collections import defaultdict

# %%
from random import randrange

# %%
import random

# %% [markdown]
# For Downloading Nltk punkt tokenizer

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Vinci\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Datasets Description
#
# 1. CMU Book Summary Dataset
#     - It contains Summary of plots of 16,559 books extracted from wikipedia
#     - Ref:
#         https://www.kaggle.com/applecrazy/cmu-book-summary-dataset
#
# 2. Movie Plots Dataset
#     - It contains descriptions of 34,886 movies from around the world. We will be working with plots coloumn.
#     - Ref:
#         https://www.kaggle.com/jrobischon/wikipedia-movie-plots

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# ### CMU Book  Summary Dataset

# %%
cn_BookSummary=['Wikipedia article ID','Freebase ID','Book title','Author','Publication date','Book genres' 
                ,'Plot summary']
df_BookSummary=pd.read_csv('./data/booksummaries/booksummaries.txt',delimiter='\t',header=None,names=cn_BookSummary)
df_BookSummary
# Out:
#        Wikipedia article ID Freebase ID  \
# 0                       620     /m/0hhy
# 1                       843     /m/0k36
# 2                       986     /m/0ldx
# 3                      1756     /m/0sww
# 4                      2080     /m/0wkt
# ...                     ...         ...
# 16554              36934824  /m/0m0p0hr
# 16555              37054020  /m/04f1nbs
# 16556              37122323  /m/0n5236t
# 16557              37132319  /m/0n4bqb1
# 16558              37159503   /m/073nkd
#
#                                               Book title              Author  \
# 0                                            Animal Farm       George Orwell
# 1                                     A Clockwork Orange     Anthony Burgess
# 2                                             The Plague        Albert Camus
# 3              An Enquiry Concerning Human Understanding          David Hume
# 4                                   A Fire Upon the Deep        Vernor Vinge
# ...                                                  ...                 ...
# 16554                                     Under Wildwood         Colin Meloy
# 16555                                  Transfer of Power         Vince Flynn
# 16556                                            Decoded               Jay-Z
# 16557  America Again: Re-becoming The Greatness We Ne...     Stephen Colbert
# 16558                                          Poor Folk  Fyodor Dostoyevsky
#
#       Publication date                                        Book genres  \
# 0           1945-08-17  {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1                 1962  {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2                 1947  {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 3                  NaN                                                NaN
# 4                  NaN  {"/m/03lrw": "Hard science fiction", "/m/06n90...
# ...                ...                                                ...
# 16554       2012-09-25                                                NaN
# 16555       2000-06-01   {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction"}
# 16556       2010-11-16                       {"/m/0xdf": "Autobiography"}
# 16557       2012-10-02                                                NaN
# 16558             1846  {"/m/02ql9": "Epistolary novel", "/m/014dfn": ...
#
#                                             Plot summary
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 3       The argument of the Enquiry proceeds by a ser...
# 4       The novel posits that space around the Milky ...
# ...                                                  ...
# 16554   Prue McKeel, having rescued her brother from ...
# 16555   The reader first meets Rapp while he is doing...
# 16556   The book follows very rough chronological ord...
# 16557   Colbert addresses topics including Wall Stree...
# 16558   Makar Devushkin and Varvara Dobroselova are s...
#
# [16559 rows x 7 columns]

# %%
rowsToPick=1000

# %%
df_BookSummary=df_BookSummary.iloc[:rowsToPick]
df_BookSummary
# Out:
#      Wikipedia article ID Freebase ID  \
# 0                     620     /m/0hhy
# 1                     843     /m/0k36
# 2                     986     /m/0ldx
# 3                    1756     /m/0sww
# 4                    2080     /m/0wkt
# ..                    ...         ...
# 995                395880   /m/0238zr
# 996                396639   /m/023cpd
# 997                397398   /m/023gj6
# 998                398809   /m/023lp2
# 999                398933   /m/023m32
#
#                                     Book title           Author  \
# 0                                  Animal Farm    George Orwell
# 1                           A Clockwork Orange  Anthony Burgess
# 2                                   The Plague     Albert Camus
# 3    An Enquiry Concerning Human Understanding       David Hume
# 4                         A Fire Upon the Deep     Vernor Vinge
# ..                                         ...              ...
# 995                           The Black Dahlia     James Ellroy
# 996                              Invisible Man    Ralph Ellison
# 997                        The Bourne Identity    Robert Ludlum
# 998                          The Gripping Hand  Jerry Pournelle
# 999                                    Redwall    Brian Jacques
#
#     Publication date                                        Book genres  \
# 0         1945-08-17  {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1               1962  {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2               1947  {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 3                NaN                                                NaN
# 4                NaN  {"/m/03lrw": "Hard science fiction", "/m/06n90...
# ..               ...                                                ...
# 995          1987-09  {"/m/0lsxr": "Crime Fiction", "/m/02n4kr": "My...
# 996             1952  {"/m/06n90": "Science Fiction", "/m/0dwly": "C...
# 997          1980-02  {"/m/01jfsb": "Thriller", "/m/02n4kr": "Myster...
# 998              NaN  {"/m/06n90": "Science Fiction", "/m/014dfn": "...
# 999              NaN  {"/m/0dwly": "Children's literature", "/m/01hm...
#
#                                           Plot summary
# 0     Old Major, the old boar on the Manor Farm, ca...
# 1     Alex, a teenager living in near-future Englan...
# 2     The text of The Plague is divided into five p...
# 3     The argument of the Enquiry proceeds by a ser...
# 4     The novel posits that space around the Milky ...
# ..                                                 ...
# 995   In June, 1943 patrol officer Dwight "Bucky" B...
# 996   In the beginning, the narrator lives in a sma...
# 997   In the stormy Mediterranean Sea, a man is fou...
# 998   At the end of The Mote in God's Eye, Renner a...
# 999   A young mouse named Matthias dreams of times ...
#
# [1000 rows x 7 columns]

# %%
pd.options.display.max_rows = 10
pd.options.display.max_colwidth=100
df_plotSummaryBooks=pd.DataFrame(df_BookSummary['Plot summary'],dtype=str)
df_plotSummaryBooks.columns=['Plot']
df_plotSummaryBooks
# Out:
#                                                                                                     Plot
# 0     Old Major, the old boar on the Manor Farm, calls the animals on the farm for a meeting, where h...
# 1     Alex, a teenager living in near-future England, leads his gang on nightly orgies of opportunist...
# 2     The text of The Plague is divided into five parts. In the town of Oran, thousands of rats, init...
# 3     The argument of the Enquiry proceeds by a series of incremental steps, separated into chapters ...
# 4     The novel posits that space around the Milky Way is divided into concentric layers called Zones...
# ..                                                                                                   ...
# 995   In June, 1943 patrol officer Dwight "Bucky" Bleichert, a former boxer and a member of the Los A...
# 996   In the beginning, the narrator lives in a small town in the South. A model student, indeed the ...
# 997   In the stormy Mediterranean Sea, a man is found floating in the water by a small ship. He has s...
# 998   At the end of The Mote in God's Eye, Renner and Bury are secretly enlisted into Imperial Naval ...
# 999   A young mouse named Matthias dreams of times of adventure rather than a life of quiet servitude...
#
# [1000 rows x 1 columns]

# %%
print("Rows in Book Plot Summary:",df_plotSummaryBooks.shape[0])
# Out:
# Rows in Book Plot Summary: 1000

# %% [markdown]
# ### Movie Plot Dataset

# %%
df_moviesSummary=pd.read_csv('./data/wiki_movie_plots.csv')
df_moviesSummary
# Out:
#        Release Year                             Title Origin/Ethnicity  \
# 0              1901            Kansas Saloon Smashers         American
# 1              1901     Love by the Light of the Moon         American
# 2              1901           The Martyred Presidents         American
# 3              1901  Terrible Teddy, the Grizzly King         American
# 4              1902            Jack and the Beanstalk         American
# ...             ...                               ...              ...
# 34881          2014                 The Water Diviner          Turkish
# 34882          2017                Çalgı Çengi İkimiz          Turkish
# 34883          2017                      Olanlar Oldu          Turkish
# 34884          2017                  Non-Transferable          Turkish
# 34885          2017                İstanbul Kırmızısı          Turkish
#
#                                  Director  \
# 0                                 Unknown
# 1                                 Unknown
# 2                                 Unknown
# 3                                 Unknown
# 4      George S. Fleming, Edwin S. Porter
# ...                                   ...
# 34881             Director: Russell Crowe
# 34882                      Selçuk Aydemir
# 34883                         Hakan Algül
# 34884                     Brendan Bradley
# 34885                      Ferzan Özpetek
#
#                                                                                                       Cast  \
# 0                                                                                                      NaN
# 1                                                                                                      NaN
# 2                                                                                                      NaN
# 3                                                                                                      NaN
# 4                                                                                                      NaN
# ...                                                                                                    ...
# 34881  Director: Russell Crowe\r\nCast: Russell Crowe, Olga Kurylenko, Jai Courtney, Cem Yılmaz, Yılmaz...
# 34882                                                                            Ahmet Kural, Murat Cemcir
# 34883                                                                Ata Demirer, Tuvana Türkay, Ülkü Duru
# 34884                             YouTubers Shanna Malcolm, Shira Lazar, Sara Fletcher and Ashley Clements
# 34885                                            Halit Ergenç, Tuba Büyüküstün, Mehmet Günsür, Nejat İşler
#
#                  Genre  \
# 0              unknown
# 1              unknown
# 2              unknown
# 3              unknown
# 4              unknown
# ...                ...
# 34881          unknown
# 34882           comedy
# 34883           comedy
# 34884  romantic comedy
# 34885         romantic
#
#                                                                        Wiki Page  \
# 0                           https://en.wikipedia.org/wiki/Kansas_Saloon_Smashers
# 1                    https://en.wikipedia.org/wiki/Love_by_the_Light_of_the_Moon
# 2                          https://en.wikipedia.org/wiki/The_Martyred_Presidents
# 3                 https://en.wikipedia.org/wiki/Terrible_Teddy,_the_Grizzly_King
# 4               https://en.wikipedia.org/wiki/Jack_and_the_Beanstalk_(1902_film)
# ...                                                                          ...
# 34881                            https://en.wikipedia.org/wiki/The_Water_Diviner
# 34882       https://en.wikipedia.org/wiki/%C3%87alg%C4%B1_%C3%87engi_%C4%B0kimiz
# 34883                                 https://en.wikipedia.org/wiki/Olanlar_Oldu
# 34884                      https://en.wikipedia.org/wiki/Non-Transferable_(film)
# 34885  https://en.wikipedia.org/wiki/%C4%B0stanbul_K%C4%B1rm%C4%B1z%C4%B1s%C4%B1
#
#                                                                                                       Plot
# 0      A bartender is working at a saloon, serving drinks to customers. After he fills a stereotypicall...
# 1      The moon, painted with a smiling face hangs over a park at night. A young couple walking past a ...
# 2      The film, just over a minute long, is composed of two shots. In the first, a girl sits at the ba...
# 3      Lasting just 61 seconds and consisting of two shots, the first shot is set in a wood during wint...
# 4      The earliest known adaptation of the classic fairytale, this films shows Jack trading his cow fo...
# ...                                                                                                    ...
# 34881  The film begins in 1919, just after World War I has ended, and centres around Joshua Connor (Rus...
# 34882                          Two musicians, Salih and Gürkan, described the adventures of their cousins.
# 34883  Zafer, a sailor living with his mother Döndü in a coastal village in Izmir, has just separated f...
# 34884  The film centres around a young woman named Amy Tyler, who books a surprise holiday to Europe wi...
# 34885  The writer Orhan Şahin returns to İstanbul after so many years to help the well-known director D...
#
# [34886 rows x 8 columns]

# %%
df_plotSummaryMovies=pd.DataFrame(df_moviesSummary['Plot'])
df_plotSummaryMovies
# Out:
#                                                                                                       Plot
# 0      A bartender is working at a saloon, serving drinks to customers. After he fills a stereotypicall...
# 1      The moon, painted with a smiling face hangs over a park at night. A young couple walking past a ...
# 2      The film, just over a minute long, is composed of two shots. In the first, a girl sits at the ba...
# 3      Lasting just 61 seconds and consisting of two shots, the first shot is set in a wood during wint...
# 4      The earliest known adaptation of the classic fairytale, this films shows Jack trading his cow fo...
# ...                                                                                                    ...
# 34881  The film begins in 1919, just after World War I has ended, and centres around Joshua Connor (Rus...
# 34882                          Two musicians, Salih and Gürkan, described the adventures of their cousins.
# 34883  Zafer, a sailor living with his mother Döndü in a coastal village in Izmir, has just separated f...
# 34884  The film centres around a young woman named Amy Tyler, who books a surprise holiday to Europe wi...
# 34885  The writer Orhan Şahin returns to İstanbul after so many years to help the well-known director D...
#
# [34886 rows x 1 columns]

# %%
df_plotSummaryMovies=df_plotSummaryMovies.iloc[:rowsToPick]
df_plotSummaryMovies
# Out:
#                                                                                                     Plot
# 0    A bartender is working at a saloon, serving drinks to customers. After he fills a stereotypicall...
# 1    The moon, painted with a smiling face hangs over a park at night. A young couple walking past a ...
# 2    The film, just over a minute long, is composed of two shots. In the first, a girl sits at the ba...
# 3    Lasting just 61 seconds and consisting of two shots, the first shot is set in a wood during wint...
# 4    The earliest known adaptation of the classic fairytale, this films shows Jack trading his cow fo...
# ..                                                                                                   ...
# 995  Alice White plays the part of a working class girl who dreams about living a life of luxury. Her...
# 996  Gentleman jewel thief A.J. Raffles (Ronald Colman) decides to give up his criminal ways as the n...
# 997  Wall Street wizard, Larry Day, new to the ways of love, is coached by his valet. He follows Vivi...
# 998  In this drama, a 50-year-old married man (played by John Halliday) goes with his wife (Belle Ben...
# 999  In remote northern Canada, Sergeant Conniston (Bickford) seeks to capture escaped convicted murd...
#
# [1000 rows x 1 columns]

# %%
print("Rows in Movies Plot Summary:",df_plotSummaryMovies.shape[0])
# Out:
# Rows in Movies Plot Summary: 1000

# %% [markdown]
# ## PreProcessing
#
# - Noise Removal
#     - removing special characters
# - Normalization
#     - Lowercase
# - Tokenization
#     - Split text into sentences
#     - Add <s> </s> for sentence start & end respectively
#     - Split sentences into words
#
# References:
#
# https://towardsdatascience.com/nlp-text-preprocessing-a-practical-guide-and-template-d80874676e79
#
# https://github.com/amanchadha/coursera-natural-language-processing-specialization/blob/master/2%20-%20Natural%20Language%20Processing%20with%20Probabilistic%20Models/Week%203/C2W3_L1_Corpus%20preprocessing%20for%20N-grams.ipynb

# %% [markdown]
# ### Removing Special Characters && To LowerCase

# %%
def preProcess(rowText):
    rowText=rowText.lower()
    rowText=re.sub(r"[^a-zA-Z,0-9.?! ]+", "", rowText)
    return rowText

# %%
df_plotSummaryBooks['Plot']=df_plotSummaryBooks['Plot'].apply(lambda row: preProcess(row))
df_plotSummaryBooks
# Out:
#                                                                                                     Plot
# 0     old major, the old boar on the manor farm, calls the animals on the farm for a meeting, where h...
# 1     alex, a teenager living in nearfuture england, leads his gang on nightly orgies of opportunisti...
# 2     the text of the plague is divided into five parts. in the town of oran, thousands of rats, init...
# 3     the argument of the enquiry proceeds by a series of incremental steps, separated into chapters ...
# 4     the novel posits that space around the milky way is divided into concentric layers called zones...
# ..                                                                                                   ...
# 995   in june, 1943 patrol officer dwight bucky bleichert, a former boxer and a member of the los ang...
# 996   in the beginning, the narrator lives in a small town in the south. a model student, indeed the ...
# 997   in the stormy mediterranean sea, a man is found floating in the water by a small ship. he has s...
# 998   at the end of the mote in gods eye, renner and bury are secretly enlisted into imperial naval i...
# 999   a young mouse named matthias dreams of times of adventure rather than a life of quiet servitude...
#
# [1000 rows x 1 columns]

# %%
df_plotSummaryMovies['Plot']=df_plotSummaryMovies['Plot'].apply(lambda row: preProcess(row))
df_plotSummaryMovies
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                                                                     Plot
# 0    a bartender is working at a saloon, serving drinks to customers. after he fills a stereotypicall...
# 1    the moon, painted with a smiling face hangs over a park at night. a young couple walking past a ...
# 2    the film, just over a minute long, is composed of two shots. in the first, a girl sits at the ba...
# 3    lasting just 61 seconds and consisting of two shots, the first shot is set in a wood during wint...
# 4    the earliest known adaptation of the classic fairytale, this films shows jack trading his cow fo...
# ..                                                                                                   ...
# 995  alice white plays the part of a working class girl who dreams about living a life of luxury. her...
# 996  gentleman jewel thief a.j. raffles ronald colman decides to give up his criminal ways as the not...
# 997  wall street wizard, larry day, new to the ways of love, is coached by his valet. he follows vivi...
# 998  in this drama, a 50yearold married man played by john halliday goes with his wife belle bennett ...
# 999  in remote northern canada, sergeant conniston bickford seeks to capture escaped convicted murder...
#
# [1000 rows x 1 columns]

# %%
corpus = "Learning% makes 'me' happy. i am happy be-cause i am learning! :)"
corpus=corpus.lower()
corpus = re.sub(r"[^a-zA-Z0-9.?! ]+", "", corpus)
print(corpus)
# Out:
# learning makes me happy. i am happy because i am learning!

# %% [markdown]
# ### WordClouds
#
# - Ref:
# https://www.kaggle.com/shwetagoyal4/wiki-movie-plots-eda?scriptVersionId=17246825

# %% [markdown]
# #### WordCloud Plot Summary Books

# %%
wordcloud = WordCloud(width = 1000, height = 600, max_font_size = 120).generate(" ".join(df_plotSummaryBooks.Plot))

plt.subplots(figsize=(18,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# #### WordCloud Plot Summary Movies

# %%
wordcloud = WordCloud(width = 1000, height = 600, max_font_size = 120).generate(" ".join(df_plotSummaryMovies.Plot))
plt.subplots(figsize=(18,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Tokenization

# %% [markdown]
# ### Text To Sentence

# %%
def addStartEndSentenceMark(sentence):
    '''
    Sentence breaken into token as parameter
    '''
    if (type(sentence) == list):
        sentence.insert(0,'<s>')
        sentence.append('</s>')
    elif (type(sentence) == str):
        sentence="<s> "+sentence+" </s>"
    return sentence

# %%
def applySentenceTokenization(sentence):
#     tokenize sentences into words
    tokens=nltk.tokenize.word_tokenize(sentence)
    return tokens

# %%
def applyTextTokenization(text):

    #     tokenize text into sentences
    listSentences=nltk.tokenize.sent_tokenize(text)

    # tokenize into words
    listSentences=[applySentenceTokenization(sentence) for sentence in listSentences]    

    #     adding start & end sentence mark
    listSentences=[addStartEndSentenceMark(sentence) for sentence in listSentences]
    
#     listSentences=[TreebankWordDetokenizer().detokenize(sentence) for sentence in listSentences]
    return listSentences

# %%
p = "Good morning, Dr. Adams. The patient is waiting for you in room number 3. Date is 19.05.2021 19:05"
# listSentences=nltk.tokenize.sent_tokenize(p)
# listSentences=[addStartEndSentenceMark(sentence) for sentence in listSentences]
# listSentences
listOfSentences=applyTextTokenization(p)
len(listOfSentences)
# Out:
# 3

# %% [markdown]
# #### Applying Tokenization
#
# - This may some time

# %%
df_plotSummaryBooks['Plot']=[applyTextTokenization(row) for row in df_plotSummaryBooks['Plot']]

# %%
df_plotSummaryBooks
# Out:
#                                                                                                     Plot
# 0    [[<s>, old, major, ,, the, old, boar, on, the, manor, farm, ,, calls, the, animals, on, the, far...
# 1    [[<s>, alex, ,, a, teenager, living, in, nearfuture, england, ,, leads, his, gang, on, nightly, ...
# 2    [[<s>, the, text, of, the, plague, is, divided, into, five, parts, ., </s>], [<s>, in, the, town...
# 3    [[<s>, the, argument, of, the, enquiry, proceeds, by, a, series, of, incremental, steps, ,, sepa...
# 4    [[<s>, the, novel, posits, that, space, around, the, milky, way, is, divided, into, concentric, ...
# ..                                                                                                   ...
# 995  [[<s>, in, june, ,, 1943, patrol, officer, dwight, bucky, bleichert, ,, a, former, boxer, and, a...
# 996  [[<s>, in, the, beginning, ,, the, narrator, lives, in, a, small, town, in, the, south, ., </s>]...
# 997  [[<s>, in, the, stormy, mediterranean, sea, ,, a, man, is, found, floating, in, the, water, by, ...
# 998  [[<s>, at, the, end, of, the, mote, in, gods, eye, ,, renner, and, bury, are, secretly, enlisted...
# 999  [[<s>, a, young, mouse, named, matthias, dreams, of, times, of, adventure, rather, than, a, life...
#
# [1000 rows x 1 columns]

# %%
df_plotSummaryMovies['Plot']=[applyTextTokenization(row) for row in df_plotSummaryMovies['Plot']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_plotSummaryMovies
# Out:
#                                                                                                     Plot
# 0    [[<s>, a, bartender, is, working, at, a, saloon, ,, serving, drinks, to, customers, ., </s>], [<...
# 1    [[<s>, the, moon, ,, painted, with, a, smiling, face, hangs, over, a, park, at, night, ., </s>],...
# 2    [[<s>, the, film, ,, just, over, a, minute, long, ,, is, composed, of, two, shots, ., </s>], [<s...
# 3    [[<s>, lasting, just, 61, seconds, and, consisting, of, two, shots, ,, the, first, shot, is, set...
# 4    [[<s>, the, earliest, known, adaptation, of, the, classic, fairytale, ,, this, films, shows, jac...
# ..                                                                                                   ...
# 995  [[<s>, alice, white, plays, the, part, of, a, working, class, girl, who, dreams, about, living, ...
# 996  [[<s>, gentleman, jewel, thief, a.j, ., </s>], [<s>, raffles, ronald, colman, decides, to, give,...
# 997  [[<s>, wall, street, wizard, ,, larry, day, ,, new, to, the, ways, of, love, ,, is, coached, by,...
# 998  [[<s>, in, this, drama, ,, a, 50yearold, married, man, played, by, john, halliday, goes, with, h...
# 999  [[<s>, in, remote, northern, canada, ,, sergeant, conniston, bickford, seeks, to, capture, escap...
#
# [1000 rows x 1 columns]

# %% [markdown]
# - Now we in each row of dataframe , we have list of list which represent tokens in sentences in text i.e Plot Summary
# - We can use these tokens to find ngrams

# %% [markdown]
# ### N-grams Tokenization

# %%
# n-grams to count mapping

def ngramCalculater(data):
    trigrams_data = defaultdict(lambda :0)
    bigrams_data = defaultdict(lambda:0)
    unigrams_data = defaultdict(lambda:0)
    N=3

    for plot in data:

        for i in range(len(plot)):
    #         into plot[i] i.e sentences in plot
            sentence=plot[i]

    #         trigrams in a sentence i.e len(sent)-2
            trigrams= [sentence[j:j+N] for j in range(len(sentence)-N+1)]
    #         bigrams in a sentence i.e len(sent)-1
            bigrams= [sentence[j:j+N-1] for j in range(len(sentence)-(N-1)+1)]
    #         unigrams in a sentence 
            unigrams= [sentence[j] for j in range(len(sentence))]

            for gram in trigrams:
                gram=(tuple(gram))
                trigrams_data[gram]+=1
            for gram in bigrams:
                gram=(tuple(gram))
                bigrams_data[gram]+=1
            for gram in unigrams:
                unigrams_data[gram]+=1
    return trigrams_data,bigrams_data,unigrams_data

# %%
books_trigrams,books_bigrams,books_unigrams=ngramCalculater(df_plotSummaryBooks['Plot'])
print("Books n-grams Details:\n - Trigrams:{}\n - Bigrams:{}\n - Unigrams{}".format(len(books_trigrams.keys()),len(books_bigrams.keys()),len(books_unigrams.keys())))
# Out:
# Books n-grams Details:
#  - Trigrams:607489
#  - Bigrams:316227
#  - Unigrams40999

# %%
movies_trigrams,movies_bigrams,movies_unigrams=ngramCalculater(df_plotSummaryMovies['Plot'])
print("Movies n-grams Details:\n - Trigrams:{}\n - Bigrams:{}\n - Unigrams{}".format(len(movies_trigrams.keys()),len(movies_bigrams.keys()),len(movies_unigrams.keys())))
# Out:
# Movies n-grams Details:
#  - Trigrams:191673
#  - Bigrams:109098
#  - Unigrams19064

# %% [markdown]
# ### creating contextual dictionary
#
# - Context(bigrams) as keys & possible candidates with probabilities as values (candidate,prob)
#
# - generated this dictionary from trigrams

# %%
# # context as key & list of (token,count) as value
# contextualDictionaryBooks={'<s>':[]}
# # dictionary from original bigram where starting sentence appear so that we can chose candidates token 

# newDict = dict(filter(lambda elem: elem[0][0]== ('<s>'), books_bigrams.items()))
# countTotal=(books_unigrams['<s>'])

# for key,value in newDict.items():
#     contextualDictionaryBooks[('<s>')].append((key[1],value/countTotal))

# %%
contextualDictionaryBooks={}

# %%
for key,value in books_bigrams.items():
    candidateToken=key[1]
    context=key[0]
    totalContextCount=books_unigrams[context]
    if (totalContextCount==0):    
        print(context)
    if (totalContextCount!=0):
        if context in contextualDictionaryBooks:
            contextualDictionaryBooks[context].append((candidateToken,value/totalContextCount))
        else:
            contextualDictionaryBooks[context]=[]
            contextualDictionaryBooks[context].append((candidateToken,value/totalContextCount))

# %%
print(context)
contextualDictionaryBooks[context]
# Out:
# churchmouse
# [(',', 1.0)]

# %%
for key,value in books_trigrams.items():
    candidateToken=key[2]
    context=(key[0],key[1])
    totalContextCount=books_bigrams[context]
    if context in contextualDictionaryBooks:
        contextualDictionaryBooks[context].append((candidateToken,value/totalContextCount))
    else:
        contextualDictionaryBooks[context]=[]
        contextualDictionaryBooks[context].append((candidateToken,value/totalContextCount))

# %%
# contextualDictionary
# for checking When at start of sentence
# for k,values in list(contextualDictionary.items()):
#     for v in values:
#         if (v[0]=='when'):
#             print(v)

#     if (v[0]=='when'):
#         print(v[0])
# dict(filter(lambda e:e[1]=='when',contextualDictionary.items()))

# %%
print(list(books_trigrams.keys())[-2][0:2])
contextualDictionaryBooks[list(books_trigrams.keys())[-2][0:2]]
# Out:
# ('churchmouse', ',')
# [('a', 1.0)]

# %% [markdown]
# ### Contextual Dictionary Movies

# %%
contextualDictionaryMovies={}

# %%
for key,value in movies_bigrams.items():
    candidateToken=key[1]
    context=key[0]
    totalContextCount=movies_unigrams[context]
    if (totalContextCount==0):    
        print(context)
    if (totalContextCount!=0):
        if context in contextualDictionaryMovies:
            contextualDictionaryMovies[context].append((candidateToken,value/totalContextCount))
        else:
            contextualDictionaryMovies[context]=[]
            contextualDictionaryMovies[context].append((candidateToken,value/totalContextCount))

# %%
print((context))
contextualDictionaryMovies[context]
# Out:
# boards
# [('the', 0.42857142857142855),
#  ('another', 0.14285714285714285),
#  ('a', 0.2857142857142857),
#  ('as', 0.14285714285714285),
#  ('the', 0.42857142857142855),
#  ('another', 0.14285714285714285),
#  ('a', 0.2857142857142857),
#  ('as', 0.14285714285714285)]

# %%
# contextualDictionaryMovies={'<s>':[]}
# newDictMovies = dict(filter(lambda elem: elem[0][0]== ('<s>'), movies_bigrams.items()))
# countTotal=(books_unigrams['<s>'])
# for key,value in newDictMovies.items():
#     contextualDictionaryBooks[('<s>')].append((key[1],value/countTotal))

# %%
for key,value in movies_trigrams.items():
    candidateToken=key[2]
    context=(key[0],key[1])
    totalContextCount=movies_bigrams[context]
    if context in contextualDictionaryMovies:
        contextualDictionaryMovies[context].append((candidateToken,value/totalContextCount))
    else:
        contextualDictionaryMovies[context]=[]
        contextualDictionaryMovies[context].append((candidateToken,value/totalContextCount))
# Out:
# [('well', 1.0)]

# %%
print(context)
contextualDictionaryMovies[context]
# Out:
# ('boards', 'as')
# [('well', 1.0)]

# %% [markdown]
# ### Text Generation

# %%
def generateRandomSentenceBooks(text):
    maxTokens=100
    tokens=applySentenceTokenization(text)

#             end of sentence ; useful for recursion 
    if (len(tokens)!=0 and (tokens[len(tokens)-1]=='.' or len(tokens)>maxTokens)):
        text=TreebankWordDetokenizer().detokenize(tokens)
        return text
    numberTokens=len(tokens)
    try:
        if (numberTokens==0):
    #         start of sentence; use <s> & predict next one
            candidates=contextualDictionaryBooks[("<s>")]
        elif (numberTokens==1):
    #         add <s> at start of tokens
            candidates=contextualDictionaryBooks[("<s>",tokens[0])]
        elif ((tokens[numberTokens-2],tokens[numberTokens-1]) in contextualDictionaryBooks.keys()):
            candidates=contextualDictionaryBooks[(tokens[numberTokens-2],tokens[numberTokens-1])]            
        else:
            candidates=contextualDictionaryBooks[tokens[numberTokens-1]]
            
    except KeyError:
#         chosing random unigram we don't have much info related to context
        candidate="<s>"
        while (candidate in ["<s>","</s>"]):
            index=randrange(len(books_unigrams.keys()))
            candidate=list(books_unigrams.keys())[index]
        text+=" "+candidate
        return generateRandomSentenceBooks(text)
    #     now we need to chose from candidates
    try:
        sampleSize=10
        indicesToSample=random.sample(range(len(candidates)), sampleSize)
    except ValueError:
        sampleSize=len(candidates)
        indicesToSample=random.sample(range(len(candidates)), sampleSize)    
    
    index=indicesToSample[0]
    maxProb=candidates[index][1]
    for i in indicesToSample:
        if (candidates[index][1]>maxProb):
            index=i
#     index=randrange(len(candidates))
    text+=" "+candidates[index][0]
    return generateRandomSentenceBooks(text)

# %%
def generateRandomSentenceMovies(text):
    maxTokens=100
    tokens=applySentenceTokenization(text)
 
    if (len(tokens)!=0 and (tokens[len(tokens)-1]=='.' or len(tokens)>maxTokens)):
        text=TreebankWordDetokenizer().detokenize(tokens)
        return text

    numberTokens=len(tokens)
    try:
        if (numberTokens==0):
            candidates=contextualDictionaryMovies[("<s>")]
        elif (numberTokens==1):
            candidates=contextualDictionaryMovies[("<s>",tokens[0])]

        elif ((tokens[numberTokens-2],tokens[numberTokens-1]) in contextualDictionaryMovies.keys()):
            candidates=contextualDictionaryMovies[(tokens[numberTokens-2],tokens[numberTokens-1])]            
        else:
#             print("in unigram context")
            candidates=contextualDictionaryMovies[tokens[numberTokens-1]]
    except KeyError:
        candidate="<s>"
        while (candidate in ["<s>","</s>"]):
            index=randrange(len(movies_unigrams.keys()))
            candidate=list(movies_unigrams.keys())[index]
        text+=" "+candidate
        return generateRandomSentenceMovies(text)

    try:
        sampleSize=10
        indicesToSample=random.sample(range(len(candidates)), sampleSize)
    except ValueError:
        sampleSize=len(candidates)
        indicesToSample=random.sample(range(len(candidates)), sampleSize)    
    
    index=indicesToSample[0]
    maxProb=candidates[index][1]
    for i in indicesToSample:
        if (candidates[index][1]>maxProb):
            index=i
#     index=randrange(len(candidates))
    text+=" "+candidates[index][0]
    return generateRandomSentenceMovies(text)

# %% [markdown]
# ## Try The Sentence Generator

# %%
text=input ("Enter Text For Sentence Generation: ")
# text=""
text=text.lower()
print("Text Using Books Data:\n"+generateRandomSentenceBooks(text))
print("\n")
print("Text Using Movies Data:\n"+generateRandomSentenceMovies(text))
# Out:
# Text Using Books Data:
# combined with biffs earthy debauchery, leads the armies and officials that maintain his spirit, without any international political influence, finn considers asking for marriage.
#
#
# Text Using Movies Data:
# zanfield isnt interested in her safe, as they go through the fire and takes his hand addressed to the image on his head.soon afterwards, a brooklyn cutie, goes abroad and develops into a relationship with the marxes is one of jims departure for africa.
